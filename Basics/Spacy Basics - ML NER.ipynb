# %%
import spacy
from spacy.lang.en import English
from spacy.pipeline import EntityRuler
import json

# %%
text = '''Mr Dursley was the director of a firm called Grunnings which made drills He was a big beefy man with hardly any neck although he did have a very large mustache Mrs Dursley was thin and blonde and had nearly twice the usual amount of neck which came in very useful as she spent so much of her time craning over garden fences spying on the neighbors The Dursleys had a small son called Dudley and in their opinion there was no finer boy anywhere'''

# %%
nlp = spacy.load("en_core_web_lg")
doc = nlp(text)
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Mr Dursley PERSON
# Grunnings ORG
# Mrs Dursley PERSON
# Dursleys PERSON
# Dudley PERSON

# %%
text = '''Today is Nov 18th 2019.'''
doc = nlp(text)
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Nov 18th 2019 DATE

# %%
#### How to use spacy to generate a set of rules to perform rules based NER
#### Generate training data using these rules to train spacy NER model

# %%
def load_data(file):

    with open(file, "r",encoding="utf-8") as f:
        data = json.load(f)
    return(data)


def generate_better_characters(file):
    hp_chars = load_data(file)
    new_characs = []
    for items in hp_chars:
        new_characs = new_characs + [items]
    print(len(new_characs))
    for items in hp_chars:
        items = items.replace("the","").replace("The","").replace("and","").replace("And","")
        items = items.replace("(","").replace(")","")
        names = items.split()
        for name in names:
            name = name.strip()
            name = name.split(",")
            new_characs = new_characs + name
    print(len(new_characs))
    final_chars = []
    new_characs = list(set(new_characs))
    print(len(new_characs))
    titles = ['Dr.', 'Mr.', 'Mrs.', 'Professor','Ms.','Miss', 'Aunt','Uncle','Mr. and Mrs.']
    for char in new_characs:
        if "" != char:
            final_chars = final_chars + new_characs
            for title in titles:
                titled_char = title + " " + char
                final_chars = final_chars + [ titled_char]
    final_chars = list(set(final_chars) - set([''])) 
    print(len(final_chars))
    final_chars.sort()
    return(final_chars)
generate_better_characters("hp_characters.json")
# Out:
# 207
# 609
# 506
# 5049
# ['Abbott',
#  'Aberforth',
#  'Aberforth Dumbledore',
#  'Alastor',
#  'Alastor (Mad-Eye) Moody',
#  'Albert',
#  'Albert Runcorn',
#  'Albus',
#  'Albus Dumbledore',
#  'Albus Severus Potter',
#  'Alecto',
#  'Alecto Carrow',
#  'Alice',
#  'Alice Longbottom',
#  'Alicia',
#  'Alicia Spinnet',
#  'Amelia',
#  'Amelia Bones',
#  'Amos',
#  'Amos Diggory',
#  'Amycus',
#  'Amycus Carrow',
#  'Andromeda Tonks',
#  'Angelina',
#  'Angelina Johnson',
#  'Anthony',
#  'Anthony Goldstein',
#  'Antioch',
#  'Antioch, Cadmus, and Ignotus Peverell',
#  'Antonin',
#  'Antonin Dolohov',
#  'Arabella',
#  'Arabella Figg',
#  'Aragog',
#  'Argus',
#  'Argus Filch',
#  'Ariana',
#  'Ariana Dumbledore',
#  'Arthur',
#  'Arthur Weasley',
#  'Augusta',
#  'Augusta Longbottom',
#  'Augustus',
#  'Augustus Rookwood',
#  'Aunt',
#  'Aunt Abbott',
#  'Aunt Aberforth',
#  'Aunt Aberforth Dumbledore',
#  'Aunt Alastor',
#  'Aunt Alastor (Mad-Eye) Moody',
#  'Aunt Albert',
#  'Aunt Albert Runcorn',
#  'Aunt Albus',
#  'Aunt Albus Dumbledore',
#  'Aunt Albus Severus Potter',
#  'Aunt Alecto',
#  'Aunt Alecto Carrow',
#  'Aunt Alice',
#  'Aunt Alice Longbottom',
#  'Aunt Alicia',
#  'Aunt Alicia Spinnet',
#  'Aunt Amelia',
#  'Aunt Amelia Bones',
#  'Aunt Amos',
#  'Aunt Amos Diggory',
#  'Aunt Amycus',
#  'Aunt Amycus Carrow',
#  'Aunt Andromeda Tonks',
#  'Aunt Angelina',
#  'Aunt Angelina Johnson',
#  'Aunt Anthony',
#  'Aunt Anthony Goldstein',
#  'Aunt Antioch',
#  'Aunt Antioch, Cadmus, and Ignotus Peverell',
#  'Aunt Antonin',
#  'Aunt Antonin Dolohov',
#  'Aunt Arabella',
#  'Aunt Arabella Figg',
#  'Aunt Aragog',
#  'Aunt Argus',
#  'Aunt Argus Filch',
#  'Aunt Ariana',
#  'Aunt Ariana Dumbledore',
#  'Aunt Arthur',
#  'Aunt Arthur Weasley',
#  'Aunt Augusta',
#  'Aunt Augusta Longbottom',
#  'Aunt Augustus',
#  'Aunt Augustus Rookwood',
#  'Aunt Aunt',
#  'Aunt Aurora',
#  'Aunt Aurora Sinistra',
#  'Aunt Bagman',
#  'Aunt Bagshot',
#  'Aunt Bane',
#  'Aunt Bard',
#  'Aunt Baron',
#  'Aunt Barty',
#  'Aunt Barty Crouch Jr',
#  'Aunt Barty Crouch Sr',
#  'Aunt Bathilda',
#  'Aunt Bathilda Bagshot',
#  'Aunt Beedle',
#  'Aunt Beedle the Bard',
#  'Aunt Bell',
#  'Aunt Bellatrix',
#  'Aunt Bellatrix Lestrange',
#  'Aunt Bill',
#  'Aunt Bill Weasley',
#  'Aunt Binns',
#  'Aunt Black',
#  'Aunt Blaise',
#  'Aunt Blaise Zabini',
#  'Aunt Bloody',
#  'Aunt Bob',
#  'Aunt Bob Ogden',
#  'Aunt Bogrod',
#  'Aunt Bones',
#  'Aunt Boot',
#  'Aunt Brown',
#  'Aunt Bryce',
#  'Aunt Buckbeak',
#  'Aunt Bulstrode',
#  'Aunt Burbage',
#  'Aunt Cadmus',
#  'Aunt Cadogan',
#  'Aunt Carrow',
#  'Aunt Cattermole',
#  'Aunt Cedric',
#  'Aunt Cedric Diggory',
#  'Aunt Chang',
#  'Aunt Charity',
#  'Aunt Charity Burbage',
#  'Aunt Charlie',
#  'Aunt Charlie Weasley',
#  'Aunt Cho',
#  'Aunt Cho Chang',
#  'Aunt Clearwater',
#  'Aunt Cole',
#  'Aunt Colin',
#  'Aunt Colin Creevey',
#  'Aunt Corban',
#  'Aunt Corban Yaxley',
#  'Aunt Cormac',
#  'Aunt Cormac McLaggen',
#  'Aunt Cornelius',
#  'Aunt Cornelius Fudge',
#  'Aunt Corner',
#  'Aunt Crabbe',
#  'Aunt Creevey',
#  'Aunt Cresswell',
#  'Aunt Crookshanks',
#  'Aunt Crouch',
#  'Aunt Cuthbert',
#  'Aunt Cuthbert Binns',
#  'Aunt Davies',
#  'Aunt Dawlish',
#  'Aunt Dean',
#  'Aunt Dean Thomas',
#  'Aunt Dedalus',
#  'Aunt Dedalus Diggle',
#  'Aunt Delacour',
#  'Aunt Demelza',
#  'Aunt Demelza Robins',
#  'Aunt Dennis',
#  'Aunt Dennis Creevey',
#  'Aunt Diggle',
#  'Aunt Diggory',
#  'Aunt Dirk',
#  'Aunt Dirk Cresswell',
#  'Aunt Dobby',
#  'Aunt Doge',
#  'Aunt Dolohov',
#  'Aunt Dolores',
#  'Aunt Dolores Umbridge',
#  'Aunt Draco',
#  'Aunt Draco Malfoy',
#  'Aunt Dudley',
#  'Aunt Dudley Dursley',
#  'Aunt Dumbledore',
#  'Aunt Dursley',
#  'Aunt Edgecombe',
#  'Aunt Elphias',
#  'Aunt Elphias Doge',
#  'Aunt Emmeline',
#  'Aunt Emmeline Vance',
#  'Aunt Ernie',
#  'Aunt Ernie Macmillan',
#  'Aunt Errol',
#  'Aunt Fang',
#  'Aunt Fat',
#  'Aunt Fawkes',
#  'Aunt Fenrir',
#  'Aunt Fenrir Greyback',
#  'Aunt Figg',
#  'Aunt Filch',
#  'Aunt Filius',
#  'Aunt Filius Flitwick',
#  'Aunt Finch-Fletchley',
#  'Aunt Finnigan',
#  'Aunt Firenze',
#  'Aunt Fletcher',
#  'Aunt Fleur',
#  'Aunt Fleur Delacour',
#  'Aunt Flint',
#  'Aunt Flitwick',
#  'Aunt Florean',
#  'Aunt Florean Fortescue',
#  'Aunt Fluffy',
#  'Aunt Fortescue',
#  'Aunt Frank',
#  'Aunt Frank Bryce',
#  'Aunt Frank Longbottom',
#  'Aunt Fred',
#  'Aunt Fred Weasley',
#  'Aunt Friar',
#  'Aunt Fudge',
#  'Aunt Gabrielle',
#  'Aunt Gabrielle Delacour',
#  'Aunt Garrick',
#  'Aunt Garrick Ollivander',
#  'Aunt Gaunt',
#  'Aunt Gellert',
#  'Aunt Gellert Grindelwald',
#  'Aunt George',
#  'Aunt George Weasley',
#  'Aunt Gilderoy',
#  'Aunt Gilderoy Lockhart',
#  'Aunt Ginny',
#  'Aunt Ginny Weasley',
#  'Aunt Goldstein',
#  'Aunt Gornuk',
#  'Aunt Goyle',
#  'Aunt Graham',
#  'Aunt Graham Montague',
#  'Aunt Granger',
#  'Aunt Grawp',
#  'Aunt Great',
#  'Aunt Great Aunt Muriel',
#  'Aunt Gregorovitch',
#  'Aunt Gregory',
#  'Aunt Gregory Goyle',
#  'Aunt Grey',
#  'Aunt Greyback',
#  'Aunt Grindelwald',
#  'Aunt Griphook',
#  'Aunt Griselda',
#  'Aunt Griselda Marchbanks',
#  'Aunt Grubbly-Plank',
#  'Aunt Hagrid',
#  'Aunt Hannah',
#  'Aunt Hannah Abbott',
#  'Aunt Harry',
#  'Aunt Harry Potter',
#  'Aunt Headless',
#  'Aunt Hedwig',
#  'Aunt Helena',
#  'Aunt Helena Ravenclaw',
#  'Aunt Hermione',
#  'Aunt Hermione Granger',
#  'Aunt Hokey',
#  'Aunt Hooch',
#  'Aunt Hopkirk',
#  'Aunt Horace',
#  'Aunt Horace Slughorn',
#  'Aunt Hugo',
#  'Aunt Hugo Weasley',
#  'Aunt Ignotus',
#  'Aunt Igor',
#  'Aunt Igor Karkaroff',
#  'Aunt Irma',
#  'Aunt Irma Pince',
#  'Aunt James',
#  'Aunt James Potter',
#  'Aunt James Sirius Potter',
#  'Aunt John',
#  'Aunt John Dawlish',
#  'Aunt Johnson',
#  'Aunt Jordan',
#  'Aunt Jr',
#  'Aunt Jr.',
#  'Aunt Justin',
#  'Aunt Justin Finch-Fletchley',
#  'Aunt Karkaroff',
#  'Aunt Katie',
#  'Aunt Katie Bell',
#  'Aunt Kendra',
#  'Aunt Kendra Dumbledore',
#  'Aunt Kettleburn',
#  'Aunt Kingsley',
#  'Aunt Kingsley Shacklebolt',
#  'Aunt Kreacher',
#  'Aunt Krum',
#  'Aunt Lady',
#  'Aunt Lavender',
#  'Aunt Lavender Brown',
#  'Aunt Lee',
#  'Aunt Lee Jordan',
#  'Aunt Lestrange',
#  'Aunt Lily',
#  'Aunt Lily Luna Potter',
#  'Aunt Lily Potter',
#  'Aunt Lockhart',
#  'Aunt Longbottom',
#  'Aunt Lord',
#  'Aunt Lord Voldemort (Tom Marvolo Riddle)',
#  'Aunt Lovegood',
#  'Aunt Lucius',
#  'Aunt Lucius Malfoy',
#  'Aunt Ludo',
#  'Aunt Ludo Bagman',
#  'Aunt Luna',
#  'Aunt Luna Lovegood',
#  'Aunt Lupin',
#  'Aunt Macmillan',
#  'Aunt Macnair',
#  'Aunt Mad-Eye',
#  'Aunt Madam',
#  'Aunt Madam Malkin',
#  'Aunt Madam Rosmerta',
#  'Aunt Mafalda',
#  'Aunt Mafalda Hopkirk',
#  'Aunt Magorian',
#  'Aunt Malfoy',
#  'Aunt Malkin',
#  'Aunt Marchbanks',
#  'Aunt Marcus',
#  'Aunt Marcus Flint',
#  'Aunt Marge',
#  'Aunt Marge Dursley',
#  'Aunt Marietta',
#  'Aunt Marietta Edgecombe',
#  'Aunt Marvolo',
#  'Aunt Marvolo Gaunt',
#  'Aunt Mary',
#  'Aunt Mary Cattermole',
#  'Aunt Mary Riddle',
#  'Aunt Maxime',
#  'Aunt McGonagall',
#  'Aunt McLaggen',
#  'Aunt Merope',
#  'Aunt Merope Gaunt',
#  'Aunt Michael',
#  'Aunt Michael Corner',
#  'Aunt Millicent',
#  'Aunt Millicent Bulstrode',
#  'Aunt Minerva',
#  'Aunt Minerva McGonagall',
#  'Aunt Moaning',
#  'Aunt Moaning Myrtle',
#  'Aunt Molly',
#  'Aunt Molly Weasley',
#  'Aunt Montague',
#  'Aunt Moody',
#  'Aunt Morfin',
#  'Aunt Morfin Gaunt',
#  'Aunt Mrs.',
#  'Aunt Mrs. Cole',
#  'Aunt Mundungus',
#  'Aunt Mundungus Fletcher',
#  'Aunt Muriel',
#  'Aunt Myrtle',
#  'Aunt Myrtle Warren',
#  'Aunt Nagini',
#  'Aunt Narcissa',
#  'Aunt Narcissa Malfoy',
#  'Aunt Nearly',
#  'Aunt Nearly Headless Nick',
#  'Aunt Neville',
#  'Aunt Neville Longbottom',
#  'Aunt Newt',
#  'Aunt Newt Scamander',
#  'Aunt Nick',
#  'Aunt Nigellus',
#  'Aunt Norbert',
#  'Aunt Nott',
#  'Aunt Nymphadora',
#  'Aunt Nymphadora Tonks',
#  'Aunt Ogden',
#  'Aunt Oliver',
#  'Aunt Oliver Wood',
#  'Aunt Olliver',
#  'Aunt Olympe',
#  'Aunt Olympe Maxime',
#  'Aunt Padma',
#  'Aunt Padma Patil',
#  'Aunt Pansy',
#  'Aunt Pansy Parkinson',
#  'Aunt Parkinson',
#  'Aunt Parvati',
#  'Aunt Parvati Patil',
#  'Aunt Patil',
#  'Aunt Peeves',
#  'Aunt Penelope',
#  'Aunt Penelope Clearwater',
#  'Aunt Percival',
#  'Aunt Percival Dumbledore',
#  'Aunt Percy',
#  'Aunt Percy Weasley',
#  'Aunt Peter',
#  'Aunt Peter Pettigrew',
#  'Aunt Pettigrew',
#  'Aunt Petunia',
#  'Aunt Petunia Dursley',
#  'Aunt Peverell',
#  'Aunt Phineas',
#  'Aunt Phineas Nigellus Black',
#  'Aunt Pigwidgeon',
#  'Aunt Pince',
#  'Aunt Pius',
#  'Aunt Pius Thicknesse',
#  'Aunt Podmore',
#  'Aunt Pomfrey',
#  'Aunt Pomona',
#  'Aunt Pomona Sprout',
#  'Aunt Poppy',
#  'Aunt Poppy Pomfrey',
#  'Aunt Potter',
#  'Aunt Quirinus',
#  'Aunt Quirinus Quirrell',
#  'Aunt Quirrell',
#  'Aunt Rabastan',
#  'Aunt Rabastan Lestrange',
#  'Aunt Ravenclaw',
#  'Aunt Reginald',
#  'Aunt Reginald Cattermole',
#  'Aunt Remus',
#  'Aunt Remus Lupin',
#  'Aunt Riddle',
#  'Aunt Rita',
#  'Aunt Rita Skeeter',
#  'Aunt Robins',
#  'Aunt Rodolphus',
#  'Aunt Rodolphus Lestrange',
#  'Aunt Roger',
#  'Aunt Roger Davies',
#  'Aunt Rola',
#  'Aunt Rolanda Hooch',
#  'Aunt Romilda',
#  'Aunt Romilda Vane',
#  'Aunt Ron',
#  'Aunt Ron Weasley',
#  'Aunt Ronan',
#  'Aunt Rookwood',
#  'Aunt Rose',
#  'Aunt Rose Weasley',
#  'Aunt Rosmerta',
#  'Aunt Rowena',
#  'Aunt Rowena Ravenclaw',
#  'Aunt Rowle',
#  'Aunt Rubeus',
#  'Aunt Rubeus Hagrid',
#  'Aunt Rufus',
#  'Aunt Rufus Scrimgeour',
#  'Aunt Runcorn',
#  'Aunt Salazar',
#  'Aunt Salazar Slytherin',
#  'Aunt Scabbers',
#  'Aunt Scabior',
#  'Aunt Scamer',
#  'Aunt Scorpius',
#  'Aunt Scorpius Malfoy',
#  'Aunt Scrimgeour',
#  'Aunt Seamus',
#  'Aunt Seamus Finnigan',
#  'Aunt Septima',
#  'Aunt Septima Vector',
#  'Aunt Severus',
#  'Aunt Severus Snape',
#  'Aunt Shacklebolt',
#  'Aunt Shunpike',
#  'Aunt Silvanus',
#  'Aunt Silvanus Kettleburn',
#  'Aunt Sinistra',
#  'Aunt Sir',
#  'Aunt Sir Cadogan',
#  'Aunt Sirius',
#  'Aunt Sirius Black',
#  'Aunt Skeeter',
#  'Aunt Slughorn',
#  'Aunt Slyrin',
#  'Aunt Smith',
#  'Aunt Snape',
#  'Aunt Spinnet',
#  'Aunt Sprout',
#  'Aunt Sr',
#  'Aunt Sr.',
#  'Aunt Stan',
#  'Aunt Stan Shunpike',
#  'Aunt Sturgis',
#  'Aunt Sturgis Podmore',
#  'Aunt Susan',
#  'Aunt Susan Bones',
#  'Aunt Sybill',
#  'Aunt Sybill Trelawney',
#  'Aunt Ted',
#  'Aunt Ted Tonks',
#  'Aunt Teddy',
#  'Aunt Teddy Lupin',
#  'Aunt Terry',
#  'Aunt Terry Boot',
#  'Aunt The Bloody Baron',
#  'Aunt The Fat Friar',
#  'Aunt The Fat Lady',
#  'Aunt The Grey Lady',
#  'Aunt Theodore Nott',
#  'Aunt Thicknesse',
#  'Aunt Thomas',
#  'Aunt Thomas Marvolo Riddle',
#  'Aunt Thomas Riddle Jr.',
#  'Aunt Thomas Riddle Sr.',
#  'Aunt Thorfinn',
#  'Aunt Thorfinn Rowle',
#  'Aunt Tom',
#  'Aunt Tonks',
#  'Aunt Travers',
#  'Aunt Trelawney',
#  'Aunt Trevor',
#  'Aunt Twycross',
#  'Aunt Umbridge',
#  'Aunt Vance',
#  'Aunt Vane',
#  'Aunt Vector',
#  'Aunt Vernon',
#  'Aunt Vernon Dursley',
#  'Aunt Viktor',
#  'Aunt Viktor Krum',
#  'Aunt Vincent',
#  'Aunt Vincent Crabbe',
#  'Aunt Voldemort',
#  'Aunt Walburga',
#  'Aunt Walburga Black',
#  'Aunt Walden',
#  'Aunt Walden Macnair',
#  'Aunt Warren',
#  'Aunt Weasley',
#  'Aunt Wilhelmina',
#  'Aunt Wilhelmina Grubbly-Plank',
#  'Aunt Wilkie',
#  'Aunt Wilkie Twycross',
#  'Aunt Winky',
#  'Aunt Wood',
#  'Aunt Xenophilius',
#  'Aunt Xenophilius Lovegood',
#  'Aunt Yaxley',
#  'Aunt Zabini',
#  'Aunt Zacharias',
#  'Aunt Zacharias Smith',
#  'Aunt odore',
#  'Aunt romeda',
#  'Aurora',
#  'Aurora Sinistra',
#  'Bagman',
#  'Bagshot',
#  'Bane',
#  'Bard',
#  'Baron',
#  'Barty',
#  'Barty Crouch Jr',
#  'Barty Crouch Sr',
#  'Bathilda',
#  'Bathilda Bagshot',
#  'Beedle',
#  'Beedle the Bard',
#  'Bell',
#  'Bellatrix',
#  'Bellatrix Lestrange',
#  'Bill',
#  'Bill Weasley',
#  'Binns',
#  'Black',
#  'Blaise',
#  'Blaise Zabini',
#  'Bloody',
#  'Bob',
#  'Bob Ogden',
#  'Bogrod',
#  'Bones',
#  'Boot',
#  'Brown',
#  'Bryce',
#  'Buckbeak',
#  'Bulstrode',
#  'Burbage',
#  'Cadmus',
#  'Cadogan',
#  'Carrow',
#  'Cattermole',
#  'Cedric',
#  'Cedric Diggory',
#  'Chang',
#  'Charity',
#  'Charity Burbage',
#  'Charlie',
#  'Charlie Weasley',
#  'Cho',
#  'Cho Chang',
#  'Clearwater',
#  'Cole',
#  'Colin',
#  'Colin Creevey',
#  'Corban',
#  'Corban Yaxley',
#  'Cormac',
#  'Cormac McLaggen',
#  'Cornelius',
#  'Cornelius Fudge',
#  'Corner',
#  'Crabbe',
#  'Creevey',
#  'Cresswell',
#  'Crookshanks',
#  'Crouch',
#  'Cuthbert',
#  'Cuthbert Binns',
#  'Davies',
#  'Dawlish',
#  'Dean',
#  'Dean Thomas',
#  'Dedalus',
#  'Dedalus Diggle',
#  'Delacour',
#  'Demelza',
#  'Demelza Robins',
#  'Dennis',
#  'Dennis Creevey',
#  'Diggle',
#  'Diggory',
#  'Dirk',
#  'Dirk Cresswell',
#  'Dobby',
#  'Doge',
#  'Dolohov',
#  'Dolores',
#  'Dolores Umbridge',
#  'Dr. Abbott',
#  'Dr. Aberforth',
#  'Dr. Aberforth Dumbledore',
#  'Dr. Alastor',
#  'Dr. Alastor (Mad-Eye) Moody',
#  'Dr. Albert',
#  'Dr. Albert Runcorn',
#  'Dr. Albus',
#  'Dr. Albus Dumbledore',
#  'Dr. Albus Severus Potter',
#  'Dr. Alecto',
#  'Dr. Alecto Carrow',
#  'Dr. Alice',
#  'Dr. Alice Longbottom',
#  'Dr. Alicia',
#  'Dr. Alicia Spinnet',
#  'Dr. Amelia',
#  'Dr. Amelia Bones',
#  'Dr. Amos',
#  'Dr. Amos Diggory',
#  'Dr. Amycus',
#  'Dr. Amycus Carrow',
#  'Dr. Andromeda Tonks',
#  'Dr. Angelina',
#  'Dr. Angelina Johnson',
#  'Dr. Anthony',
#  'Dr. Anthony Goldstein',
#  'Dr. Antioch',
#  'Dr. Antioch, Cadmus, and Ignotus Peverell',
#  'Dr. Antonin',
#  'Dr. Antonin Dolohov',
#  'Dr. Arabella',
#  'Dr. Arabella Figg',
#  'Dr. Aragog',
#  'Dr. Argus',
#  'Dr. Argus Filch',
#  'Dr. Ariana',
#  'Dr. Ariana Dumbledore',
#  'Dr. Arthur',
#  'Dr. Arthur Weasley',
#  'Dr. Augusta',
#  'Dr. Augusta Longbottom',
#  'Dr. Augustus',
#  'Dr. Augustus Rookwood',
#  'Dr. Aunt',
#  'Dr. Aurora',
#  'Dr. Aurora Sinistra',
#  'Dr. Bagman',
#  'Dr. Bagshot',
#  'Dr. Bane',
#  'Dr. Bard',
#  'Dr. Baron',
#  'Dr. Barty',
#  'Dr. Barty Crouch Jr',
#  'Dr. Barty Crouch Sr',
#  'Dr. Bathilda',
#  'Dr. Bathilda Bagshot',
#  'Dr. Beedle',
#  'Dr. Beedle the Bard',
#  'Dr. Bell',
#  'Dr. Bellatrix',
#  'Dr. Bellatrix Lestrange',
#  'Dr. Bill',
#  'Dr. Bill Weasley',
#  'Dr. Binns',
#  'Dr. Black',
#  'Dr. Blaise',
#  'Dr. Blaise Zabini',
#  'Dr. Bloody',
#  'Dr. Bob',
#  'Dr. Bob Ogden',
#  'Dr. Bogrod',
#  'Dr. Bones',
#  'Dr. Boot',
#  'Dr. Brown',
#  'Dr. Bryce',
#  'Dr. Buckbeak',
#  'Dr. Bulstrode',
#  'Dr. Burbage',
#  'Dr. Cadmus',
#  'Dr. Cadogan',
#  'Dr. Carrow',
#  'Dr. Cattermole',
#  'Dr. Cedric',
#  'Dr. Cedric Diggory',
#  'Dr. Chang',
#  'Dr. Charity',
#  'Dr. Charity Burbage',
#  'Dr. Charlie',
#  'Dr. Charlie Weasley',
#  'Dr. Cho',
#  'Dr. Cho Chang',
#  'Dr. Clearwater',
#  'Dr. Cole',
#  'Dr. Colin',
#  'Dr. Colin Creevey',
#  'Dr. Corban',
#  'Dr. Corban Yaxley',
#  'Dr. Cormac',
#  'Dr. Cormac McLaggen',
#  'Dr. Cornelius',
#  'Dr. Cornelius Fudge',
#  'Dr. Corner',
#  'Dr. Crabbe',
#  'Dr. Creevey',
#  'Dr. Cresswell',
#  'Dr. Crookshanks',
#  'Dr. Crouch',
#  'Dr. Cuthbert',
#  'Dr. Cuthbert Binns',
#  'Dr. Davies',
#  'Dr. Dawlish',
#  'Dr. Dean',
#  'Dr. Dean Thomas',
#  'Dr. Dedalus',
#  'Dr. Dedalus Diggle',
#  'Dr. Delacour',
#  'Dr. Demelza',
#  'Dr. Demelza Robins',
#  'Dr. Dennis',
#  'Dr. Dennis Creevey',
#  'Dr. Diggle',
#  'Dr. Diggory',
#  'Dr. Dirk',
#  'Dr. Dirk Cresswell',
#  'Dr. Dobby',
#  'Dr. Doge',
#  'Dr. Dolohov',
#  'Dr. Dolores',
#  'Dr. Dolores Umbridge',
#  'Dr. Draco',
#  'Dr. Draco Malfoy',
#  'Dr. Dudley',
#  'Dr. Dudley Dursley',
#  'Dr. Dumbledore',
#  'Dr. Dursley',
#  'Dr. Edgecombe',
#  'Dr. Elphias',
#  'Dr. Elphias Doge',
#  'Dr. Emmeline',
#  'Dr. Emmeline Vance',
#  'Dr. Ernie',
#  'Dr. Ernie Macmillan',
#  'Dr. Errol',
#  'Dr. Fang',
#  'Dr. Fat',
#  'Dr. Fawkes',
#  'Dr. Fenrir',
#  'Dr. Fenrir Greyback',
#  'Dr. Figg',
#  'Dr. Filch',
#  'Dr. Filius',
#  'Dr. Filius Flitwick',
#  'Dr. Finch-Fletchley',
#  'Dr. Finnigan',
#  'Dr. Firenze',
#  'Dr. Fletcher',
#  'Dr. Fleur',
#  'Dr. Fleur Delacour',
#  'Dr. Flint',
#  'Dr. Flitwick',
#  'Dr. Florean',
#  'Dr. Florean Fortescue',
#  'Dr. Fluffy',
#  'Dr. Fortescue',
#  'Dr. Frank',
#  'Dr. Frank Bryce',
#  'Dr. Frank Longbottom',
#  'Dr. Fred',
#  'Dr. Fred Weasley',
#  'Dr. Friar',
#  'Dr. Fudge',
#  'Dr. Gabrielle',
#  'Dr. Gabrielle Delacour',
#  'Dr. Garrick',
#  'Dr. Garrick Ollivander',
#  'Dr. Gaunt',
#  'Dr. Gellert',
#  'Dr. Gellert Grindelwald',
#  'Dr. George',
#  'Dr. George Weasley',
#  'Dr. Gilderoy',
#  'Dr. Gilderoy Lockhart',
#  'Dr. Ginny',
#  'Dr. Ginny Weasley',
#  'Dr. Goldstein',
#  'Dr. Gornuk',
#  'Dr. Goyle',
#  'Dr. Graham',
#  'Dr. Graham Montague',
#  'Dr. Granger',
#  'Dr. Grawp',
#  'Dr. Great',
#  'Dr. Great Aunt Muriel',
#  'Dr. Gregorovitch',
#  'Dr. Gregory',
#  'Dr. Gregory Goyle',
#  'Dr. Grey',
#  'Dr. Greyback',
#  'Dr. Grindelwald',
#  'Dr. Griphook',
#  'Dr. Griselda',
#  'Dr. Griselda Marchbanks',
#  'Dr. Grubbly-Plank',
#  'Dr. Hagrid',
#  'Dr. Hannah',
#  'Dr. Hannah Abbott',
#  'Dr. Harry',
#  'Dr. Harry Potter',
#  'Dr. Headless',
#  'Dr. Hedwig',
#  'Dr. Helena',
#  'Dr. Helena Ravenclaw',
#  'Dr. Hermione',
#  'Dr. Hermione Granger',
#  'Dr. Hokey',
#  'Dr. Hooch',
#  'Dr. Hopkirk',
#  'Dr. Horace',
#  'Dr. Horace Slughorn',
#  'Dr. Hugo',
#  'Dr. Hugo Weasley',
#  'Dr. Ignotus',
#  'Dr. Igor',
#  'Dr. Igor Karkaroff',
#  'Dr. Irma',
#  'Dr. Irma Pince',
#  'Dr. James',
#  'Dr. James Potter',
#  'Dr. James Sirius Potter',
#  'Dr. John',
#  'Dr. John Dawlish',
#  'Dr. Johnson',
#  'Dr. Jordan',
#  'Dr. Jr',
#  'Dr. Jr.',
#  'Dr. Justin',
#  'Dr. Justin Finch-Fletchley',
#  'Dr. Karkaroff',
#  'Dr. Katie',
#  'Dr. Katie Bell',
#  'Dr. Kendra',
#  'Dr. Kendra Dumbledore',
#  'Dr. Kettleburn',
#  'Dr. Kingsley',
#  'Dr. Kingsley Shacklebolt',
#  'Dr. Kreacher',
#  'Dr. Krum',
#  'Dr. Lady',
#  'Dr. Lavender',
#  'Dr. Lavender Brown',
#  'Dr. Lee',
#  'Dr. Lee Jordan',
#  'Dr. Lestrange',
#  'Dr. Lily',
#  'Dr. Lily Luna Potter',
#  'Dr. Lily Potter',
#  'Dr. Lockhart',
#  'Dr. Longbottom',
#  'Dr. Lord',
#  'Dr. Lord Voldemort (Tom Marvolo Riddle)',
#  'Dr. Lovegood',
#  'Dr. Lucius',
#  'Dr. Lucius Malfoy',
#  'Dr. Ludo',
#  'Dr. Ludo Bagman',
#  'Dr. Luna',
#  'Dr. Luna Lovegood',
#  'Dr. Lupin',
#  'Dr. Macmillan',
#  'Dr. Macnair',
#  'Dr. Mad-Eye',
#  'Dr. Madam',
#  'Dr. Madam Malkin',
#  'Dr. Madam Rosmerta',
#  'Dr. Mafalda',
#  'Dr. Mafalda Hopkirk',
#  'Dr. Magorian',
#  'Dr. Malfoy',
#  'Dr. Malkin',
#  'Dr. Marchbanks',
#  'Dr. Marcus',
#  'Dr. Marcus Flint',
#  'Dr. Marge',
#  'Dr. Marge Dursley',
#  'Dr. Marietta',
#  'Dr. Marietta Edgecombe',
#  'Dr. Marvolo',
#  'Dr. Marvolo Gaunt',
#  'Dr. Mary',
#  'Dr. Mary Cattermole',
#  'Dr. Mary Riddle',
#  'Dr. Maxime',
#  'Dr. McGonagall',
#  'Dr. McLaggen',
#  'Dr. Merope',
#  'Dr. Merope Gaunt',
#  'Dr. Michael',
#  'Dr. Michael Corner',
#  'Dr. Millicent',
#  'Dr. Millicent Bulstrode',
#  'Dr. Minerva',
#  'Dr. Minerva McGonagall',
#  'Dr. Moaning',
#  'Dr. Moaning Myrtle',
#  'Dr. Molly',
#  'Dr. Molly Weasley',
#  'Dr. Montague',
#  'Dr. Moody',
#  'Dr. Morfin',
#  'Dr. Morfin Gaunt',
#  'Dr. Mrs.',
#  'Dr. Mrs. Cole',
#  'Dr. Mundungus',
#  'Dr. Mundungus Fletcher',
#  'Dr. Muriel',
#  'Dr. Myrtle',
#  'Dr. Myrtle Warren',
#  'Dr. Nagini',
#  'Dr. Narcissa',
#  'Dr. Narcissa Malfoy',
#  'Dr. Nearly',
#  'Dr. Nearly Headless Nick',
#  'Dr. Neville',
#  'Dr. Neville Longbottom',
#  'Dr. Newt',
#  'Dr. Newt Scamander',
#  'Dr. Nick',
#  'Dr. Nigellus',
#  'Dr. Norbert',
#  'Dr. Nott',
#  'Dr. Nymphadora',
#  'Dr. Nymphadora Tonks',
#  'Dr. Ogden',
#  'Dr. Oliver',
#  'Dr. Oliver Wood',
#  'Dr. Olliver',
#  'Dr. Olympe',
#  'Dr. Olympe Maxime',
#  'Dr. Padma',
#  'Dr. Padma Patil',
#  'Dr. Pansy',
#  'Dr. Pansy Parkinson',
#  'Dr. Parkinson',
#  'Dr. Parvati',
#  'Dr. Parvati Patil',
#  'Dr. Patil',
#  'Dr. Peeves',
#  'Dr. Penelope',
#  'Dr. Penelope Clearwater',
#  'Dr. Percival',
#  'Dr. Percival Dumbledore',
#  'Dr. Percy',
#  'Dr. Percy Weasley',
#  'Dr. Peter',
#  'Dr. Peter Pettigrew',
#  'Dr. Pettigrew',
#  'Dr. Petunia',
#  'Dr. Petunia Dursley',
#  'Dr. Peverell',
#  'Dr. Phineas',
#  'Dr. Phineas Nigellus Black',
#  'Dr. Pigwidgeon',
#  'Dr. Pince',
#  'Dr. Pius',
#  ...]

# %%
def create_training_data(file, type):
    data = generate_better_characters(file)
    patterns = []
    for item in data:
        pattern = {
            "label": type,
            "pattern":item
        }
        patterns = patterns + [pattern]
    return(patterns)

def generate_rules(patterns):
    nlp = English()
    ruler = EntityRuler(nlp)
    ruler = nlp.add_pipe("entity_ruler")
    ruler.add_patterns(patterns)
#     uler.add_patterns([{"label": "ORG", "pattern": "Apple"}])
    nlp.to_disk("hp_ner")

    
patterns = create_training_data("hp_characters.json", "PERSON")
generate_rules(patterns)
# Out:
# 207
# 609
# 506
# 5049

# %%
nlp = spacy.load("hp_ner")

# %%
def test_model(model,text):
    doc = nlp(text)
    result = []
    for ent in doc.ents:
        result = result + [ent]
    return(result)

with open("hpchapter1.txt","r",encoding="utf-8") as f:
    text = f.read()
    le_data = {}
    chapters = text.split("CHAPTER")[1:]
    for chapter in chapters:
        chapter_num, chapter_title = chapter.split("\n\n")[0:2]
        segments = chapter.split("\n\n")[2:]
        hits = list()
        for segment in segments:
            segment = segment.replace("\n"," ").strip()
            results = test_model(nlp,segment)
            for result in  results:
                hits = hits + [result]
        le_data[chapter_num] = list(set(hits))

print(le_data)
# Out:
# {' ONE': [Dumbledore, Sirius Black, James Potter, Mrs. Dursley, Professor McGonagall, Mrs. Dursley, Voldemort, Dudley, Petunia, Professor McGonagall, Mr. Dursley, Professor McGonagall, Dudley, Mrs. Dursley, Hagrid, Professor McGonagall, Professor McGonagall, Harry, Lily, Ted, Pomfrey, Dumbledore, Dudley, Dumbledore, Dudley, Professor McGonagall, Dumbledore, Mr. Dursley, Mrs. Dursley, Mr. Dursley, Dumbledore, Harry, Hagrid, Professor McGonagall, Voldemort, Dumbledore, Mr. Dursley, Dumbledore, Albus Dumbledore, Harry, Mr. Dursley, Dudley, Mr. Dursley, Harry, Mrs. Dursley, Dumbledore, Harry, Professor McGonagall, Lily, Professor Dumbledore, Mr. Dursley, Mr. and Mrs. Dursley, Mrs. Dursley, Voldemort, Mrs. Dursley, Mr. Dursley, Hagrid, Professor McGonagall, Dumbledore, Mr. Dursley, Mrs. Dursley, Hagrid, Petunia, Dumbledore, Professor McGonagall, Professor McGonagall, James, Hagrid, Mr. Dursley, Dumbledore, Dumbledore, Albus, Professor McGonagall, Professor McGonagall, Dumbledore, Mr. Dursley, Mrs. Dursley, Harry Potter, Mr. Dursley, Professor McGonagall, Hagrid, Dudley, Mr. Dursley, Voldemort, Mrs. Dursley, Dumbledore, Harry Potter, Dumbledore, Dumbledore, Dumbledore, Harry, Harry, Mr. Dursley, Potter, Mr. Dursley, Harry, Professor McGonagall, Potter, Dumbledore, Dumbledore, Professor McGonagall, Professor McGonagall, Potter, Harry, Dumbledore, Dumbledore, Mr. Dursley, Dudley, Hagrid, Harry, Potter, Dumbledore, Voldemort, Dumbledore, Mrs., Professor McGonagall, Dumbledore, Hagrid, Mrs. Potter, James, Mrs. Dursley, Mr. Dursley, Mr. Dursley, Mr. Dursley, Harry, Sirius, Mrs. Dursley, Mrs. Dursley, Mr. Dursley, Professor McGonagall, Mr. and Mrs. Dursley, Mr. Dursley, Hagrid, Voldemort, Mrs. Dursley, Professor McGonagall, Hagrid, Dedalus Diggle, Mrs. Dursley, Professor McGonagall, Dudley, Dumbledore, Professor McGonagall, Dumbledore, Harry, Mrs. Dursley, Mr. Dursley, Dumbledore, Professor McGonagall, Mr. Dursley, Harry Potter, Harry, Professor McGonagall, Harry Potter, Albus Dumbledore, Lily, Professor McGonagall, Professor Dumbledore, Mr. Dursley, Dudley, Harry Potter, Dumbledore, Dumbledore, Harry, Hagrid, Mr. Dursley, Hagrid, Dumbledore, Hagrid, Madam, Mr. Dursley, Mr. Dursley, Harry, Petunia, Dumbledore, Dumbledore, Professor McGonagall, Dumbledore, Mr. Dursley, Mrs. Dursley, Hagrid], ' TWO': [Mr. Dursley, Aunt Petunia, Dudley, Harry, Harry, Dudley, Dudley, Harry, Aunt Petunia, Aunt Petunia, Vernon, Harry, Harry Potter, Harry, Harry, Harry, Dudley, Harry, Harry, Uncle Vernon, Mrs. Figg, Harry, Aunt Petunia, Aunt Petunia, Harry, Dudley, Aunt Petunia, Marge, Uncle Vernon, Harry, Dudley, Harry, Harry, Harry, Harry Potter, Harry, Dudley, Dudley, Uncle Vernon, Dudley, Aunt Petunia, Dudley, Dudley, Harry, Dudley, Mrs. Figg, Harry, Marge, Harry, Dudley, Harry, Uncle Vernon, Harry, Uncle Vernon, Harry, Aunt Petunia, Dudley, Harry, Harry, Uncle Vernon, Harry, Aunt Petunia, Uncle Vernon, Aunt Petunia, Nearly, Harry, Dudley, Harry, Aunt Petunia, Aunt Petunia, Uncle Vernon, Harry, Nearly, Dudley, Harry, Dudley, Harry, Uncle Vernon, Dudley, Dudley, Dudley, Dudley, Harry, Harry, Aunt Petunia, Aunt Petunia, Uncle Vernon, Harry, Dudley, Harry, Dudley, Harry, Aunt Petunia, Harry, Harry, Dudley, Harry, Dudley, Harry, Harry, Harry, Aunt Petunia, Harry, Dudley, Dudley, Harry, Aunt Petunia, Dudley, Dudley, Dudley, Dudley, Uncle Vernon, Harry, Dudley, Dudley, Harry, Aunt Petunia, Aunt Petunia, Dudley, Harry, Dudley, Mrs. Figg, Aunt Petunia, Uncle Vernon, Dudley, Dudley, Harry, Harry, Dudley, Harry, Harry, Mrs. Figg, Dudley, Uncle Vernon, Harry, Mrs. Figg, Dudley, Dudley, Harry, Harry, Harry, Harry, Uncle Vernon, Harry, Harry, Harry, Harry, Vernon, Harry, Dudley Dursley, Dudley, Harry, Harry, Uncle Vernon, Dudley, Harry, Harry, Harry, Harry, Harry, Harry, Lord, Harry, Harry, Uncle Vernon, Dudley, Aunt Petunia, Dudley, Dudley, Harry, Dudley, Harry, Harry, Dudley, Harry, Dudley, Aunt Petunia, Dudley, Dudley, Harry, Dudley, Uncle Vernon, Harry, Uncle Vernon, ...
